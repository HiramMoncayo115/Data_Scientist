# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar el dataset
df = pd.read_csv("C:/Users/xps/Desktop/Desarrollos_2025/Data Scientist/Analisis exploratorio de datos/Data/Titanic-Dataset.csv")

# Mostrar primeras 5 filas
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 📊 Análisis Univariado
#
# En esta sección exploraremos **una variable a la vez** para entender mejor su distribución.
#
# Ejemplos:
# - Distribución de edades.
# - Proporción de género.
# - Precios de los boletos (`Fare`).
# - Supervivencia (`Survived`).

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"].dropna(), bins=30, kde=True, color="skyblue")
plt.title("Distribución de edades de los pasajeros", fontsize=14)
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Sex", data=df, palette="pastel")
plt.title("Distribución por género", fontsize=14)
plt.xlabel("Género")
plt.ylabel("Cantidad")
plt.show()
# Out:
# C:\Users\xps\AppData\Local\Temp\ipykernel_16796\2241083971.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Sex", data=df, palette="pastel")

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Fare"], bins=40, kde=False, color="lightgreen")
plt.title("Distribución de tarifas (Fare)", fontsize=14)
plt.xlabel("Tarifa")
plt.ylabel("Número de pasajeros")
plt.xlim(0, 300)  # Limitamos para quitar outliers extremos
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Survived", data=df, palette="Set1")
plt.title("Distribución de supervivencia (0 = No, 1 = Sí)", fontsize=14)
plt.xlabel("¿Sobrevivió?")
plt.ylabel("Cantidad")
plt.show()
# Out:
# C:\Users\xps\AppData\Local\Temp\ipykernel_16796\2220466505.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Survived", data=df, palette="Set1")

# %% [markdown]
# # ✅ Conclusiones del análisis univariado
#
# - La mayoría de pasajeros eran adultos jóvenes (20–40 años).
# - Había más hombres que mujeres en el barco.
# - La mayoría de boletos costaban poco, pero algunos pasajeros pagaron tarifas muy altas.
# - La tasa de supervivencia fue **menor al 50%**.

# %% [markdown]
# # 🔗 Análisis Bivariado
#
# En esta sección exploramos relaciones entre variables para entender mejor los factores que influyeron en la supervivencia:
#
# - **Género vs Supervivencia**
# - **Clase de boleto (Pclass) vs Supervivencia**
# - **Edad vs Supervivencia**
# - **Tarifa (Fare) vs Clase (Pclass)**

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Sex", hue="Survived", data=df, palette="Set2")
plt.title("Supervivencia según género", fontsize=14)
plt.xlabel("Género")
plt.ylabel("Cantidad")
plt.legend(title="¿Sobrevivió?", labels=["No", "Sí"])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Pclass", hue="Survived", data=df, palette="pastel")
plt.title("Supervivencia según clase de boleto", fontsize=14)
plt.xlabel("Clase (1 = Alta, 3 = Baja)")
plt.ylabel("Cantidad")
plt.legend(title="¿Sobrevivió?", labels=["No", "Sí"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x="Age", hue="Survived", bins=30, kde=False, palette="Set2")
plt.title("Distribución de edades según supervivencia", fontsize=14)
plt.xlabel("Edad")
plt.ylabel("Cantidad")
#plt.legend(title="¿Sobrevivió?", labels=["No", "Sí"])
plt.show()

# %% [markdown]
# # ✅ Conclusiones del análisis bivariado
#
# - **Género**: las mujeres tenían una probabilidad de supervivencia mucho mayor que los hombres.
# - **Clase de boleto**: los pasajeros de primera clase sobrevivieron en mayor proporción que los de tercera.
# - **Edad**: los niños pequeños tuvieron mayores probabilidades de sobrevivir que adultos mayores.
